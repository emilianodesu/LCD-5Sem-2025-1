# %%
import pandas as pd

# %% [markdown]
# # Preprocesamiento

# %%
df = pd.read_csv('./Resources/data.csv')

# %%
df.head()
# Out:
#    id     estado  antiguedad       modalidad  \
# 0   1  Chihuahua         1.0   b.\tDistancia
# 1   2   Coahuila         0.0  a.\tPresencial
# 2   3   Coahuila        10.0   b.\tDistancia
# 3   4   Coahuila         8.0   b.\tDistancia
# 4   5   Coahuila         3.0  a.\tPresencial
#
#                                                value
# 0                              Selección de personal
# 1                Diseño de programas de capacitación
# 2           Construcción de la cartografía electoral
# 3  Operación de las comisiones de vigilancia del ...
# 4        Planeación de planes, programas y proyectos

# %% [markdown]
# Mapear las modalidades a variables numericas enteras.

# %%
mapping = {"a.\tPresencial": 0, "b.\tDistancia": 1, "c.\tMixta": 2}
df['modalidad'] = df['modalidad'].replace(mapping)
df.head()
# Out:
# C:\Users\cemh0\AppData\Local\Temp\ipykernel_19888\3187455827.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['modalidad'] = df['modalidad'].replace(mapping)
#    id     estado  antiguedad  modalidad  \
# 0   1  Chihuahua         1.0          1
# 1   2   Coahuila         0.0          0
# 2   3   Coahuila        10.0          1
# 3   4   Coahuila         8.0          1
# 4   5   Coahuila         3.0          0
#
#                                                value
# 0                              Selección de personal
# 1                Diseño de programas de capacitación
# 2           Construcción de la cartografía electoral
# 3  Operación de las comisiones de vigilancia del ...
# 4        Planeación de planes, programas y proyectos

# %% [markdown]
# Filtar los datos por modalidad a distancia y agrupar los cursos con su respectiva demanda.

# %%
demanda = df[df['modalidad'] == 1].drop(columns=['modalidad'])
demanda.rename(columns={'value': 'curso'}, inplace=True)
demanda.head(15)
# Out:
#     id            estado  antiguedad  \
# 0    1         Chihuahua         1.0
# 2    3          Coahuila        10.0
# 3    4          Coahuila         8.0
# 5    6         Chihuahua        30.0
# 7    8    Aguascalientes         8.0
# 8    9          Campeche         0.0
# 9   10            Puebla         1.0
# 10  11          Veracruz         1.5
# 12  13        Guanajuato         7.0
# 13  14          Veracruz        13.0
# 16  17  Ciudad de México        30.0
# 17  18  Ciudad de México        22.0
# 20  21            Oaxaca         1.6
# 21  22            México        10.0
# 24  25   San Luis Potosí        32.0
#
#                                                 curso
# 0                               Selección de personal
# 2            Construcción de la cartografía electoral
# 3   Operación de las comisiones de vigilancia del ...
# 5   Registro de actos de partidos y agrupaciones p...
# 7   Determinación de financiamiento público a part...
# 8   Distribución de documentación y material elect...
# 9                     Administración de base de datos
# 10  Operación de las comisiones de vigilancia del ...
# 12  Registro de actos de partidos y agrupaciones p...
# 13                    Administración de base de datos
# 16                          Procesamiento informático
# 17  Administración de tecnología de información y ...
# 20  Aplicación y gestión de recursos humanos, mate...
# 21               Diseño de materiales de capacitación
# 24           Construcción de la cartografía electoral

# %%
cursos = demanda['curso'].value_counts().reset_index()
cursos.columns = ['curso', 'counts']
cursos
# Out:
#                                                 curso  counts
# 0                       Atención de asuntos jurídicos     235
# 1   Aplicación y gestión de recursos humanos, mate...     190
# 2                               Selección de personal     170
# 3   Operación de las comisiones de vigilancia del ...     156
# 4                     Administración de base de datos     145
# 5   Actualización del padrón electoral y credencia...     132
# 6            Construcción de la cartografía electoral     129
# 7                     Depuración del padrón electoral     127
# 8               Fiscalización a los sujetos obligados     127
# 9                         Impartición de capacitación     121
# 10         Operación de módulos de atención ciudadana     113
# 11        Planeación de planes, programas y proyectos     113
# 12  Aplicación de metodología estadística y/o demo...     111
# 13       Seguimiento de planes, programas y proyectos      92
# 14                Diseño de programas de capacitación      92
# 15               Diseño de materiales de capacitación      90
# 16  Ubicación, equipamiento e instalación de casil...      85
# 17  Administración de tecnología de información y ...      84
# 18        Evaluación de planes, programas y proyectos      82
# 19                            Desarrollo de normativa      72
# 20                          Procesamiento informático      69
# 21  Determinación de financiamiento público a part...      66
# 22  Registro de actos de partidos y agrupaciones p...      62
# 23                Reincorporación al padrón electoral      61
# 24  Almacenamiento de documentación y material ele...      57
# 25  Distribución de documentación y material elect...      57
# 26                             Desarrollo de sistemas      56
# 27  Verificación de sesiones de los órganos descon...      52
# 28                  Verificación del padrón electoral      50
# 29  Diseño, mejora y producción de documentación e...      41
# 30  Diseño, mejora y producción de material electoral      41
# 31  Integración de mesas directivas de casilla o s...      40
# 32  Administración de los tiempos del estado en ra...      40
# 33               Administración de centros de cómputo      20
# 34  Ejecución de los procedimientos para administr...      20
# 35   Gestión de franquicias postales y/o telegráficas       4

# %% [markdown]
# Estructuras de datos para el algoritmo

# %%
cursos = cursos.sort_values(by=['counts'], ascending=False)
demanda = demanda.merge(cursos, on='curso', how='left')
demanda = demanda.sort_values(by=['counts', 'curso', 'antiguedad'], ascending=False)
demanda.drop(columns=['counts'], inplace=True)
# Estructuras de datos
lista_demanda = demanda.to_dict(orient='records')
lista_cursos = cursos.to_dict(orient='records')

# %% [markdown]
# Previews

# %%
lista_demanda
# Out:
# [{'id': 1422,
#   'estado': 'Guanajuato',
#   'antiguedad': 36.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1719,
#   'estado': 'Ciudad de México',
#   'antiguedad': 32.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 385,
#   'estado': 'Jalisco',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 563,
#   'estado': 'México',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 125,
#   'estado': 'Yucatán',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 454,
#   'estado': 'Michoacán',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1039,
#   'estado': 'Nuevo León',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1794,
#   'estado': 'Morelos',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 754,
#   'estado': 'Ciudad de México',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 764,
#   'estado': 'Nuevo León',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1844,
#   'estado': 'Guanajuato',
#   'antiguedad': 31.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 596,
#   'estado': 'México',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 747,
#   'estado': 'México',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 850,
#   'estado': 'México',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 990,
#   'estado': 'Querétaro',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1612,
#   'estado': 'Chiapas',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1722,
#   'estado': 'Tabasco',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1732,
#   'estado': 'Nuevo León',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 17,
#   'estado': 'Ciudad de México',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 843,
#   'estado': 'Ciudad de México',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 946,
#   'estado': 'Chiapas',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2097,
#   'estado': 'Sinaloa',
#   'antiguedad': 30.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1885,
#   'estado': 'Guerrero',
#   'antiguedad': 29.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 560,
#   'estado': 'Ciudad de México',
#   'antiguedad': 29.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1005,
#   'estado': 'Veracruz',
#   'antiguedad': 29.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1428,
#   'estado': 'Aguascalientes',
#   'antiguedad': 29.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1593,
#   'estado': 'Puebla',
#   'antiguedad': 29.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1986,
#   'estado': 'Michoacán',
#   'antiguedad': 29.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2166,
#   'estado': 'San Luis Potosí',
#   'antiguedad': 29.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1829,
#   'estado': 'San Luis Potosí',
#   'antiguedad': 29.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2121,
#   'estado': 'Oaxaca',
#   'antiguedad': 29.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1386,
#   'estado': 'México',
#   'antiguedad': 28.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 147,
#   'estado': 'Guerrero',
#   'antiguedad': 28.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 423,
#   'estado': 'Tlaxcala',
#   'antiguedad': 28.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1823,
#   'estado': 'Durango',
#   'antiguedad': 28.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1968,
#   'estado': 'Zacatecas',
#   'antiguedad': 28.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1625,
#   'estado': 'Hidalgo',
#   'antiguedad': 28.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2113,
#   'estado': 'Michoacán',
#   'antiguedad': 28.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 61,
#   'estado': 'Durango',
#   'antiguedad': 27.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1248,
#   'estado': 'Puebla',
#   'antiguedad': 27.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1707,
#   'estado': 'Puebla',
#   'antiguedad': 27.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 437,
#   'estado': 'Ciudad de México',
#   'antiguedad': 27.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 321,
#   'estado': 'Veracruz',
#   'antiguedad': 27.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2033,
#   'estado': 'Chiapas',
#   'antiguedad': 27.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 704,
#   'estado': 'Sonora',
#   'antiguedad': 26.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1429,
#   'estado': 'Aguascalientes',
#   'antiguedad': 26.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1208,
#   'estado': 'México',
#   'antiguedad': 26.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1979,
#   'estado': 'Nuevo León',
#   'antiguedad': 26.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1754,
#   'estado': 'Sonora',
#   'antiguedad': 25.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2103,
#   'estado': 'Nayarit',
#   'antiguedad': 25.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 486,
#   'estado': 'México',
#   'antiguedad': 25.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1188,
#   'estado': 'Tlaxcala',
#   'antiguedad': 25.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1322,
#   'estado': 'México',
#   'antiguedad': 25.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 158,
#   'estado': 'Nuevo León',
#   'antiguedad': 25.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1341,
#   'estado': 'México',
#   'antiguedad': 25.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2006,
#   'estado': 'Oaxaca',
#   'antiguedad': 25.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 182,
#   'estado': 'Hidalgo',
#   'antiguedad': 24.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 878,
#   'estado': 'Ciudad de México',
#   'antiguedad': 24.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1380,
#   'estado': 'Ciudad de México',
#   'antiguedad': 23.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 326,
#   'estado': 'Veracruz',
#   'antiguedad': 23.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 941,
#   'estado': 'Hidalgo',
#   'antiguedad': 23.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 365,
#   'estado': 'Chiapas',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 522,
#   'estado': 'Jalisco',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 720,
#   'estado': 'Veracruz',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 884,
#   'estado': 'Michoacán',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1094,
#   'estado': 'Tlaxcala',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1669,
#   'estado': 'Chiapas',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1909,
#   'estado': 'Puebla',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 126,
#   'estado': 'Yucatán',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 322,
#   'estado': 'Sinaloa',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 787,
#   'estado': 'México',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1192,
#   'estado': 'México',
#   'antiguedad': 22.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 329,
#   'estado': 'Aguascalientes',
#   'antiguedad': 21.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 687,
#   'estado': 'Puebla',
#   'antiguedad': 21.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 972,
#   'estado': 'Ciudad de México',
#   'antiguedad': 21.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1382,
#   'estado': 'Guanajuato',
#   'antiguedad': 21.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 868,
#   'estado': 'Ciudad de México',
#   'antiguedad': 21.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1343,
#   'estado': 'México',
#   'antiguedad': 21.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1528,
#   'estado': 'Ciudad de México',
#   'antiguedad': 21.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 697,
#   'estado': 'Quintana Roo',
#   'antiguedad': 20.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 765,
#   'estado': 'Tamaulipas',
#   'antiguedad': 20.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1388,
#   'estado': 'México',
#   'antiguedad': 20.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1657,
#   'estado': 'Tamaulipas',
#   'antiguedad': 20.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1901,
#   'estado': 'Ciudad de México',
#   'antiguedad': 20.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 242,
#   'estado': 'Ciudad de México',
#   'antiguedad': 20.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1193,
#   'estado': 'México',
#   'antiguedad': 20.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1702,
#   'estado': 'Ciudad de México',
#   'antiguedad': 20.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1932,
#   'estado': 'Veracruz',
#   'antiguedad': 20.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 89,
#   'estado': 'Tamaulipas',
#   'antiguedad': 19.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 165,
#   'estado': 'México',
#   'antiguedad': 19.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 857,
#   'estado': 'Chiapas',
#   'antiguedad': 19.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1405,
#   'estado': 'Jalisco',
#   'antiguedad': 19.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1668,
#   'estado': 'Sinaloa',
#   'antiguedad': 19.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 80,
#   'estado': 'Oaxaca',
#   'antiguedad': 18.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1650,
#   'estado': 'Ciudad de México',
#   'antiguedad': 18.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 706,
#   'estado': 'Puebla',
#   'antiguedad': 18.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 556,
#   'estado': 'Guanajuato',
#   'antiguedad': 17.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1337,
#   'estado': 'Yucatán',
#   'antiguedad': 17.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1863,
#   'estado': 'Aguascalientes',
#   'antiguedad': 17.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 489,
#   'estado': 'México',
#   'antiguedad': 16.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2068,
#   'estado': 'Guerrero',
#   'antiguedad': 16.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 412,
#   'estado': 'Ciudad de México',
#   'antiguedad': 16.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2155,
#   'estado': 'Guanajuato',
#   'antiguedad': 16.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 827,
#   'estado': 'Ciudad de México',
#   'antiguedad': 15.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1308,
#   'estado': 'Ciudad de México',
#   'antiguedad': 15.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1108,
#   'estado': 'Nuevo León',
#   'antiguedad': 14.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1274,
#   'estado': 'Guerrero',
#   'antiguedad': 14.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 111,
#   'estado': 'Ciudad de México',
#   'antiguedad': 14.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 310,
#   'estado': 'Chihuahua',
#   'antiguedad': 14.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 610,
#   'estado': 'Tlaxcala',
#   'antiguedad': 14.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 157,
#   'estado': 'Jalisco',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 264,
#   'estado': 'Tabasco',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1369,
#   'estado': 'Ciudad de México',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 73,
#   'estado': 'Guanajuato',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 496,
#   'estado': 'Jalisco',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 499,
#   'estado': 'México',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1196,
#   'estado': 'Nuevo León',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2135,
#   'estado': 'Ciudad de México',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 75,
#   'estado': 'México',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1119,
#   'estado': 'Chiapas',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1294,
#   'estado': 'Puebla',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1755,
#   'estado': 'Ciudad de México',
#   'antiguedad': 13.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 982,
#   'estado': 'Quintana Roo',
#   'antiguedad': 12.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1256,
#   'estado': 'Ciudad de México',
#   'antiguedad': 12.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 170,
#   'estado': 'Chihuahua',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 701,
#   'estado': 'Tamaulipas',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1752,
#   'estado': 'Morelos',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2168,
#   'estado': 'Ciudad de México',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 370,
#   'estado': 'México',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 883,
#   'estado': 'Veracruz',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1018,
#   'estado': 'México',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1114,
#   'estado': 'Veracruz',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 890,
#   'estado': 'Veracruz',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1539,
#   'estado': 'Puebla',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1740,
#   'estado': 'Chihuahua',
#   'antiguedad': 11.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 51,
#   'estado': 'Ciudad de México',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 160,
#   'estado': 'Ciudad de México',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1459,
#   'estado': 'Tabasco',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1484,
#   'estado': 'Puebla',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1983,
#   'estado': 'Sinaloa',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 204,
#   'estado': 'México',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 470,
#   'estado': 'México',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 792,
#   'estado': 'Guanajuato',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 895,
#   'estado': 'Hidalgo',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 996,
#   'estado': 'Ciudad de México',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1478,
#   'estado': 'Tamaulipas',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1717,
#   'estado': 'Guanajuato',
#   'antiguedad': 10.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1125,
#   'estado': 'Nayarit',
#   'antiguedad': 9.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1726,
#   'estado': 'Ciudad de México',
#   'antiguedad': 9.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1782,
#   'estado': 'Ciudad de México',
#   'antiguedad': 9.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1942,
#   'estado': 'Nuevo León',
#   'antiguedad': 9.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 277,
#   'estado': 'Jalisco',
#   'antiguedad': 8.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1140,
#   'estado': 'Chiapas',
#   'antiguedad': 8.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1408,
#   'estado': 'Ciudad de México',
#   'antiguedad': 8.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2036,
#   'estado': 'Hidalgo',
#   'antiguedad': 8.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 136,
#   'estado': 'México',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 138,
#   'estado': 'Nuevo León',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 194,
#   'estado': 'México',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1102,
#   'estado': 'Guerrero',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1143,
#   'estado': 'Nayarit',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1407,
#   'estado': 'Ciudad de México',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1765,
#   'estado': 'Ciudad de México',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2146,
#   'estado': 'Veracruz',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 161,
#   'estado': 'Chihuahua',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 579,
#   'estado': 'Tamaulipas',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 760,
#   'estado': 'México',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1255,
#   'estado': 'Ciudad de México',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1457,
#   'estado': 'Ciudad de México',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1728,
#   'estado': 'Ciudad de México',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 523,
#   'estado': 'México',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1795,
#   'estado': 'Jalisco',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1826,
#   'estado': 'Guerrero',
#   'antiguedad': 7.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1948,
#   'estado': 'Querétaro',
#   'antiguedad': 6.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 699,
#   'estado': 'Jalisco',
#   'antiguedad': 6.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 46,
#   'estado': 'Ciudad de México',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 105,
#   'estado': 'Campeche',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 599,
#   'estado': 'Ciudad de México',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 722,
#   'estado': 'Colima',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1165,
#   'estado': 'Michoacán',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1553,
#   'estado': 'Ciudad de México',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1487,
#   'estado': 'Ciudad de México',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1581,
#   'estado': 'Colima',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 93,
#   'estado': 'México',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 237,
#   'estado': 'Ciudad de México',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 567,
#   'estado': 'Ciudad de México',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1476,
#   'estado': 'México',
#   'antiguedad': 5.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 471,
#   'estado': 'Ciudad de México',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 606,
#   'estado': 'Guanajuato',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1250,
#   'estado': 'Ciudad de México',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1390,
#   'estado': 'Ciudad de México',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1443,
#   'estado': 'Ciudad de México',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2174,
#   'estado': 'Ciudad de México',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 69,
#   'estado': 'Tlaxcala',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 98,
#   'estado': 'Jalisco',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 141,
#   'estado': 'Ciudad de México',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 696,
#   'estado': 'Ciudad de México',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1162,
#   'estado': 'Zacatecas',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1538,
#   'estado': 'Veracruz',
#   'antiguedad': 4.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1213,
#   'estado': 'Coahuila',
#   'antiguedad': 2.6,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1081,
#   'estado': 'Veracruz',
#   'antiguedad': 2.5,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 341,
#   'estado': 'Quintana Roo',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 575,
#   'estado': 'México',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2082,
#   'estado': 'Baja California',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 413,
#   'estado': 'Chiapas',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 640,
#   'estado': 'Colima',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 785,
#   'estado': 'México',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1272,
#   'estado': 'México',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1602,
#   'estado': 'Hidalgo',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 482,
#   'estado': 'Tabasco',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1505,
#   'estado': 'Veracruz',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1555,
#   'estado': 'Jalisco',
#   'antiguedad': 2.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2127,
#   'estado': 'Querétaro',
#   'antiguedad': 1.8,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 21,
#   'estado': 'Oaxaca',
#   'antiguedad': 1.6,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1073,
#   'estado': 'Nayarit',
#   'antiguedad': 1.5,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 2034,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.5,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 251,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 469,
#   'estado': 'Guerrero',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 487,
#   'estado': 'Chiapas',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 545,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 778,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1055,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1060,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1500,
#   'estado': 'Michoacán',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1656,
#   'estado': 'México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1664,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1764,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 630,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 643,
#   'estado': 'Nuevo León',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1057,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1112,
#   'estado': 'Chiapas',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1242,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1610,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1643,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1822,
#   'estado': 'Querétaro',
#   'antiguedad': 1.0,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 702,
#   'estado': 'México',
#   'antiguedad': 0.1,
#   'curso': 'Atención de asuntos jurídicos'},
#  {'id': 1737,
#   'estado': 'Chiapas',
#   'antiguedad': 32.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 427,
#   'estado': 'Nuevo León',
#   'antiguedad': 32.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1880,
#   'estado': 'México',
#   'antiguedad': 32.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 416,
#   'estado': 'Baja California',
#   'antiguedad': 32.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 125,
#   'estado': 'Yucatán',
#   'antiguedad': 31.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 219,
#   'estado': 'Puebla',
#   'antiguedad': 31.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 737,
#   'estado': 'Jalisco',
#   'antiguedad': 31.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 764,
#   'estado': 'Nuevo León',
#   'antiguedad': 31.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 801,
#   'estado': 'Guanajuato',
#   'antiguedad': 31.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 384,
#   'estado': 'México',
#   'antiguedad': 31.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1794,
#   'estado': 'Morelos',
#   'antiguedad': 31.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 850,
#   'estado': 'México',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1612,
#   'estado': 'Chiapas',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 17,
#   'estado': 'Ciudad de México',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 791,
#   'estado': 'Campeche',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1021,
#   'estado': 'Colima',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1611,
#   'estado': 'Jalisco',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 47,
#   'estado': 'México',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 596,
#   'estado': 'México',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1722,
#   'estado': 'Tabasco',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1732,
#   'estado': 'Nuevo León',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1843,
#   'estado': 'Ciudad de México',
#   'antiguedad': 30.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 475,
#   'estado': 'Puebla',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 652,
#   'estado': 'México',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1180,
#   'estado': 'México',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1470,
#   'estado': 'Durango',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1260,
#   'estado': 'Coahuila',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1885,
#   'estado': 'Guerrero',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 2124,
#   'estado': 'Querétaro',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 462,
#   'estado': 'Chihuahua',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 560,
#   'estado': 'Ciudad de México',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 882,
#   'estado': 'Baja California',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1593,
#   'estado': 'Puebla',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1626,
#   'estado': 'Chiapas',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1986,
#   'estado': 'Michoacán',
#   'antiguedad': 29.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1899,
#   'estado': 'Baja California Sur',
#   'antiguedad': 28.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1171,
#   'estado': 'Ciudad de México',
#   'antiguedad': 28.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1386,
#   'estado': 'México',
#   'antiguedad': 28.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1823,
#   'estado': 'Durango',
#   'antiguedad': 28.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1968,
#   'estado': 'Zacatecas',
#   'antiguedad': 28.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1248,
#   'estado': 'Puebla',
#   'antiguedad': 27.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1525,
#   'estado': 'Sinaloa',
#   'antiguedad': 27.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1707,
#   'estado': 'Puebla',
#   'antiguedad': 27.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 437,
#   'estado': 'Ciudad de México',
#   'antiguedad': 27.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1604,
#   'estado': 'Nuevo León',
#   'antiguedad': 26.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 731,
#   'estado': 'Querétaro',
#   'antiguedad': 26.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 485,
#   'estado': 'Chihuahua',
#   'antiguedad': 25.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 486,
#   'estado': 'México',
#   'antiguedad': 25.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 2171,
#   'estado': 'Ciudad de México',
#   'antiguedad': 25.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1169,
#   'estado': 'Yucatán',
#   'antiguedad': 25.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1642,
#   'estado': 'Guanajuato',
#   'antiguedad': 25.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 814,
#   'estado': 'Ciudad de México',
#   'antiguedad': 25.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1322,
#   'estado': 'México',
#   'antiguedad': 25.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 2028,
#   'estado': 'Michoacán',
#   'antiguedad': 25.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 182,
#   'estado': 'Hidalgo',
#   'antiguedad': 24.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1557,
#   'estado': 'Guanajuato',
#   'antiguedad': 24.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 140,
#   'estado': 'Tlaxcala',
#   'antiguedad': 23.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 326,
#   'estado': 'Veracruz',
#   'antiguedad': 23.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1397,
#   'estado': 'Tlaxcala',
#   'antiguedad': 23.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 43,
#   'estado': 'México',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 126,
#   'estado': 'Yucatán',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1659,
#   'estado': 'Sinaloa',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 2071,
#   'estado': 'Jalisco',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 543,
#   'estado': 'Jalisco',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 720,
#   'estado': 'Veracruz',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1094,
#   'estado': 'Tlaxcala',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1909,
#   'estado': 'Puebla',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 119,
#   'estado': 'Guanajuato',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 571,
#   'estado': 'Ciudad de México',
#   'antiguedad': 22.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 376,
#   'estado': 'México',
#   'antiguedad': 21.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 972,
#   'estado': 'Ciudad de México',
#   'antiguedad': 21.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1329,
#   'estado': 'Veracruz',
#   'antiguedad': 21.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1382,
#   'estado': 'Guanajuato',
#   'antiguedad': 21.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 830,
#   'estado': 'México',
#   'antiguedad': 21.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 203,
#   'estado': 'México',
#   'antiguedad': 20.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 574,
#   'estado': 'México',
#   'antiguedad': 20.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 765,
#   'estado': 'Tamaulipas',
#   'antiguedad': 20.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1388,
#   'estado': 'México',
#   'antiguedad': 20.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1657,
#   'estado': 'Tamaulipas',
#   'antiguedad': 20.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 461,
#   'estado': 'Ciudad de México',
#   'antiguedad': 20.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 929,
#   'estado': 'Oaxaca',
#   'antiguedad': 20.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 857,
#   'estado': 'Chiapas',
#   'antiguedad': 19.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1953,
#   'estado': 'Michoacán',
#   'antiguedad': 19.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1952,
#   'estado': 'Tlaxcala',
#   'antiguedad': 19.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 706,
#   'estado': 'Puebla',
#   'antiguedad': 18.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1123,
#   'estado': 'México',
#   'antiguedad': 18.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 556,
#   'estado': 'Guanajuato',
#   'antiguedad': 17.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1337,
#   'estado': 'Yucatán',
#   'antiguedad': 17.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 295,
#   'estado': 'Jalisco',
#   'antiguedad': 16.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 565,
#   'estado': 'Guanajuato',
#   'antiguedad': 16.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 855,
#   'estado': 'Guanajuato',
#   'antiguedad': 16.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 956,
#   'estado': 'Veracruz',
#   'antiguedad': 16.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 548,
#   'estado': 'México',
#   'antiguedad': 16.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1409,
#   'estado': 'México',
#   'antiguedad': 16.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1324,
#   'estado': 'Chihuahua',
#   'antiguedad': 14.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1108,
#   'estado': 'Nuevo León',
#   'antiguedad': 14.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1573,
#   'estado': 'Jalisco',
#   'antiguedad': 14.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 85,
#   'estado': 'San Luis Potosí',
#   'antiguedad': 14.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1274,
#   'estado': 'Guerrero',
#   'antiguedad': 14.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 816,
#   'estado': 'Michoacán',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1294,
#   'estado': 'Puebla',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 73,
#   'estado': 'Guanajuato',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 157,
#   'estado': 'Jalisco',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 403,
#   'estado': 'Tlaxcala',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 418,
#   'estado': 'Ciudad de México',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 496,
#   'estado': 'Jalisco',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 499,
#   'estado': 'México',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 716,
#   'estado': 'Michoacán',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1435,
#   'estado': 'Sinaloa',
#   'antiguedad': 13.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1114,
#   'estado': 'Veracruz',
#   'antiguedad': 11.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 170,
#   'estado': 'Chihuahua',
#   'antiguedad': 11.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 701,
#   'estado': 'Tamaulipas',
#   'antiguedad': 11.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1740,
#   'estado': 'Chihuahua',
#   'antiguedad': 11.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 370,
#   'estado': 'México',
#   'antiguedad': 11.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 2000,
#   'estado': 'Puebla',
#   'antiguedad': 11.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 160,
#   'estado': 'Ciudad de México',
#   'antiguedad': 10.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 177,
#   'estado': 'Sinaloa',
#   'antiguedad': 10.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 181,
#   'estado': 'Oaxaca',
#   'antiguedad': 10.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1484,
#   'estado': 'Puebla',
#   'antiguedad': 10.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1983,
#   'estado': 'Sinaloa',
#   'antiguedad': 10.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 204,
#   'estado': 'México',
#   'antiguedad': 10.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1462,
#   'estado': 'Ciudad de México',
#   'antiguedad': 10.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1861,
#   'estado': 'Sonora',
#   'antiguedad': 10.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1125,
#   'estado': 'Nayarit',
#   'antiguedad': 9.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 277,
#   'estado': 'Jalisco',
#   'antiguedad': 8.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 350,
#   'estado': 'Baja California',
#   'antiguedad': 8.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 967,
#   'estado': 'San Luis Potosí',
#   'antiguedad': 8.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1950,
#   'estado': 'Quintana Roo',
#   'antiguedad': 8.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 38,
#   'estado': 'Chihuahua',
#   'antiguedad': 8.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 750,
#   'estado': 'Durango',
#   'antiguedad': 8.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 928,
#   'estado': 'Puebla',
#   'antiguedad': 8.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1158,
#   'estado': 'México',
#   'antiguedad': 8.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1372,
#   'estado': 'México',
#   'antiguedad': 8.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 579,
#   'estado': 'Tamaulipas',
#   'antiguedad': 7.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 136,
#   'estado': 'México',
#   'antiguedad': 7.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 194,
#   'estado': 'México',
#   'antiguedad': 7.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 13,
#   'estado': 'Guanajuato',
#   'antiguedad': 7.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1181,
#   'estado': 'Sonora',
#   'antiguedad': 7.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1711,
#   'estado': 'Coahuila',
#   'antiguedad': 7.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1725,
#   'estado': 'Ciudad de México',
#   'antiguedad': 7.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 2146,
#   'estado': 'Veracruz',
#   'antiguedad': 7.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1791,
#   'estado': 'Chihuahua',
#   'antiguedad': 6.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1948,
#   'estado': 'Querétaro',
#   'antiguedad': 6.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 74,
#   'estado': 'Yucatán',
#   'antiguedad': 6.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 337,
#   'estado': 'Sinaloa',
#   'antiguedad': 6.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1768,
#   'estado': 'San Luis Potosí',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 93,
#   'estado': 'México',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 105,
#   'estado': 'Campeche',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 122,
#   'estado': 'Chiapas',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 722,
#   'estado': 'Colima',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 821,
#   'estado': 'Guanajuato',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1080,
#   'estado': 'Nayarit',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1165,
#   'estado': 'Michoacán',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 825,
#   'estado': 'México',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1581,
#   'estado': 'Colima',
#   'antiguedad': 5.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 2051,
#   'estado': 'Hidalgo',
#   'antiguedad': 4.9,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1978,
#   'estado': 'Ciudad de México',
#   'antiguedad': 4.5,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 98,
#   'estado': 'Jalisco',
#   'antiguedad': 4.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 448,
#   'estado': 'Puebla',
#   'antiguedad': 4.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 283,
#   'estado': 'Sinaloa',
#   'antiguedad': 4.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 606,
#   'estado': 'Guanajuato',
#   'antiguedad': 4.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1450,
#   'estado': 'Baja California',
#   'antiguedad': 4.0,
#   'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros'},
#  {'id': 1538,
#   'estado': 'Veracruz',
#   'antiguedad': 4.0,
# ...
#  {'id': 1692,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Administración de base de datos'},
#  {'id': 1779,
#   'estado': 'Nuevo León',
#   'antiguedad': 1.0,
#   'curso': 'Administración de base de datos'},
#  {'id': 146,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Administración de base de datos'},
#  {'id': 251,
#   'estado': 'Ciudad de México',
#   'antiguedad': 1.0,
#   'curso': 'Administración de base de datos'},
#  {'id': 1392,
#   'estado': 'Yucatán',
#   'antiguedad': 1.0,
#   'curso': 'Administración de base de datos'},
#  {'id': 938,
#   'estado': 'Campeche',
#   'antiguedad': 47.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1422,
#   'estado': 'Guanajuato',
#   'antiguedad': 36.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1495,
#   'estado': 'Ciudad de México',
#   'antiguedad': 33.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1731,
#   'estado': 'México',
#   'antiguedad': 33.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1258,
#   'estado': 'México',
#   'antiguedad': 32.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1297,
#   'estado': 'Guerrero',
#   'antiguedad': 32.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2163,
#   'estado': 'Ciudad de México',
#   'antiguedad': 32.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 799,
#   'estado': 'México',
#   'antiguedad': 32.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 618,
#   'estado': 'Zacatecas',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 829,
#   'estado': 'México',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1227,
#   'estado': 'Ciudad de México',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1342,
#   'estado': 'Yucatán',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2030,
#   'estado': 'Coahuila',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 443,
#   'estado': 'Michoacán',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 655,
#   'estado': 'México',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 755,
#   'estado': 'México',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 761,
#   'estado': 'México',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 817,
#   'estado': 'Guerrero',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 828,
#   'estado': 'Tabasco',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 847,
#   'estado': 'México',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1318,
#   'estado': 'México',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1920,
#   'estado': 'Colima',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2093,
#   'estado': 'Nuevo León',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1230,
#   'estado': 'Jalisco',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1362,
#   'estado': 'Coahuila',
#   'antiguedad': 31.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 907,
#   'estado': 'Ciudad de México',
#   'antiguedad': 30.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1223,
#   'estado': 'México',
#   'antiguedad': 30.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2097,
#   'estado': 'Sinaloa',
#   'antiguedad': 30.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2118,
#   'estado': 'Sinaloa',
#   'antiguedad': 30.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1202,
#   'estado': 'Hidalgo',
#   'antiguedad': 30.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1640,
#   'estado': 'Yucatán',
#   'antiguedad': 30.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 70,
#   'estado': 'Jalisco',
#   'antiguedad': 30.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 434,
#   'estado': 'Ciudad de México',
#   'antiguedad': 29.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 507,
#   'estado': 'Michoacán',
#   'antiguedad': 29.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 757,
#   'estado': 'México',
#   'antiguedad': 29.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 875,
#   'estado': 'Campeche',
#   'antiguedad': 29.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1597,
#   'estado': 'Colima',
#   'antiguedad': 29.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1831,
#   'estado': 'Veracruz',
#   'antiguedad': 29.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1596,
#   'estado': 'Oaxaca',
#   'antiguedad': 29.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1945,
#   'estado': 'Puebla',
#   'antiguedad': 28.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 343,
#   'estado': 'Morelos',
#   'antiguedad': 28.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 774,
#   'estado': 'México',
#   'antiguedad': 28.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1802,
#   'estado': 'Ciudad de México',
#   'antiguedad': 28.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2079,
#   'estado': 'Morelos',
#   'antiguedad': 28.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 904,
#   'estado': 'Morelos',
#   'antiguedad': 28.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 955,
#   'estado': 'México',
#   'antiguedad': 28.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1344,
#   'estado': 'México',
#   'antiguedad': 27.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1012,
#   'estado': 'Campeche',
#   'antiguedad': 27.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1040,
#   'estado': 'Morelos',
#   'antiguedad': 26.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2037,
#   'estado': 'Hidalgo',
#   'antiguedad': 26.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1031,
#   'estado': 'Hidalgo',
#   'antiguedad': 26.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1511,
#   'estado': 'Veracruz',
#   'antiguedad': 26.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1576,
#   'estado': 'Veracruz',
#   'antiguedad': 26.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1839,
#   'estado': 'Durango',
#   'antiguedad': 26.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1036,
#   'estado': 'Chiapas',
#   'antiguedad': 25.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1595,
#   'estado': 'Sonora',
#   'antiguedad': 25.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1951,
#   'estado': 'Oaxaca',
#   'antiguedad': 25.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1312,
#   'estado': 'Tabasco',
#   'antiguedad': 25.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1491,
#   'estado': 'Coahuila',
#   'antiguedad': 25.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2129,
#   'estado': 'Ciudad de México',
#   'antiguedad': 25.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1188,
#   'estado': 'Tlaxcala',
#   'antiguedad': 25.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 159,
#   'estado': 'San Luis Potosí',
#   'antiguedad': 23.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 76,
#   'estado': 'Ciudad de México',
#   'antiguedad': 22.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1849,
#   'estado': 'Nayarit',
#   'antiguedad': 22.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1131,
#   'estado': 'Querétaro',
#   'antiguedad': 22.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1043,
#   'estado': 'Ciudad de México',
#   'antiguedad': 22.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1035,
#   'estado': 'Tlaxcala',
#   'antiguedad': 21.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2010,
#   'estado': 'San Luis Potosí',
#   'antiguedad': 21.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2035,
#   'estado': 'Puebla',
#   'antiguedad': 20.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2111,
#   'estado': 'Ciudad de México',
#   'antiguedad': 20.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 644,
#   'estado': 'Jalisco',
#   'antiguedad': 20.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1153,
#   'estado': 'Ciudad de México',
#   'antiguedad': 20.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1361,
#   'estado': 'México',
#   'antiguedad': 20.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 338,
#   'estado': 'Ciudad de México',
#   'antiguedad': 19.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 691,
#   'estado': 'Veracruz',
#   'antiguedad': 19.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2031,
#   'estado': 'Sonora',
#   'antiguedad': 19.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 351,
#   'estado': 'México',
#   'antiguedad': 19.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1953,
#   'estado': 'Michoacán',
#   'antiguedad': 19.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1997,
#   'estado': 'Nuevo León',
#   'antiguedad': 19.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1960,
#   'estado': 'Guerrero',
#   'antiguedad': 18.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1050,
#   'estado': 'Baja California',
#   'antiguedad': 17.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 180,
#   'estado': 'Hidalgo',
#   'antiguedad': 17.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 944,
#   'estado': 'Veracruz',
#   'antiguedad': 16.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 855,
#   'estado': 'Guanajuato',
#   'antiguedad': 16.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 517,
#   'estado': 'Puebla',
#   'antiguedad': 15.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1566,
#   'estado': 'Quintana Roo',
#   'antiguedad': 13.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 297,
#   'estado': 'México',
#   'antiguedad': 13.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1687,
#   'estado': 'Sonora',
#   'antiguedad': 13.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 435,
#   'estado': 'Veracruz',
#   'antiguedad': 12.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 436,
#   'estado': 'Yucatán',
#   'antiguedad': 11.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1410,
#   'estado': 'Nayarit',
#   'antiguedad': 11.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 356,
#   'estado': 'Coahuila',
#   'antiguedad': 11.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 894,
#   'estado': 'Ciudad de México',
#   'antiguedad': 10.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1368,
#   'estado': 'Chiapas',
#   'antiguedad': 10.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1991,
#   'estado': 'San Luis Potosí',
#   'antiguedad': 10.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 284,
#   'estado': 'Hidalgo',
#   'antiguedad': 10.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 658,
#   'estado': 'México',
#   'antiguedad': 10.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 2007,
#   'estado': 'Tamaulipas',
#   'antiguedad': 10.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 518,
#   'estado': 'México',
#   'antiguedad': 9.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 521,
#   'estado': 'Sonora',
#   'antiguedad': 9.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1594,
#   'estado': 'México',
#   'antiguedad': 8.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1412,
#   'estado': 'Guerrero',
#   'antiguedad': 8.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1683,
#   'estado': 'Querétaro',
#   'antiguedad': 5.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  {'id': 1927,
#   'estado': 'Quintana Roo',
#   'antiguedad': 5.0,
#   'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos'},
#  ...]

# %%
lista_cursos
# Out:
# [{'curso': 'Atención de asuntos jurídicos', 'counts': 235},
#  {'curso': 'Aplicación y gestión de recursos humanos, materiales y financieros',
#   'counts': 190},
#  {'curso': 'Selección de personal', 'counts': 170},
#  {'curso': 'Operación de las comisiones de vigilancia del registro federal de electores',
#   'counts': 156},
#  {'curso': 'Administración de base de datos', 'counts': 145},
#  {'curso': 'Actualización del padrón electoral y credencialización de los ciudadanos',
#   'counts': 132},
#  {'curso': 'Construcción de la cartografía electoral', 'counts': 129},
#  {'curso': 'Depuración del padrón electoral', 'counts': 127},
#  {'curso': 'Fiscalización a los sujetos obligados', 'counts': 127},
#  {'curso': 'Impartición de capacitación', 'counts': 121},
#  {'curso': 'Operación de módulos de atención ciudadana', 'counts': 113},
#  {'curso': 'Planeación de planes, programas y proyectos', 'counts': 113},
#  {'curso': 'Aplicación de metodología estadística y/o demográfica',
#   'counts': 111},
#  {'curso': 'Seguimiento de planes, programas y proyectos', 'counts': 92},
#  {'curso': 'Diseño de programas de capacitación', 'counts': 92},
#  {'curso': 'Diseño de materiales de capacitación', 'counts': 90},
#  {'curso': 'Ubicación, equipamiento e instalación de casillas o su equivalente en los distintos tipos de elección o procesos de participación ciudadana',
#   'counts': 85},
#  {'curso': 'Administración de tecnología de información y comunicaciones',
#   'counts': 84},
#  {'curso': 'Evaluación de planes, programas y proyectos', 'counts': 82},
#  {'curso': 'Desarrollo de normativa', 'counts': 72},
#  {'curso': 'Procesamiento informático', 'counts': 69},
#  {'curso': 'Determinación de financiamiento público a partidos políticos nacionales, locales y candidaturas independientes',
#   'counts': 66},
#  {'curso': 'Registro de actos de partidos y agrupaciones políticas',
#   'counts': 62},
#  {'curso': 'Reincorporación al padrón electoral', 'counts': 61},
#  {'curso': 'Almacenamiento de documentación y material electoral',
#   'counts': 57},
#  {'curso': 'Distribución de documentación y material electoral', 'counts': 57},
#  {'curso': 'Desarrollo de sistemas', 'counts': 56},
#  {'curso': 'Verificación de sesiones de los órganos desconcentrados',
#   'counts': 52},
#  {'curso': 'Verificación del padrón electoral', 'counts': 50},
#  {'curso': 'Diseño, mejora y producción de documentación electoral',
#   'counts': 41},
#  {'curso': 'Diseño, mejora y producción de material electoral', 'counts': 41},
#  {'curso': 'Integración de mesas directivas de casilla o su equivalente en los distintos tipos de elección o procesos de participación ciudadana',
#   'counts': 40},
#  {'curso': 'Administración de los tiempos del estado en radio y televisión',
#   'counts': 40},
#  {'curso': 'Administración de centros de cómputo', 'counts': 20},
#  {'curso': 'Ejecución de los procedimientos para administrar los tiempos del estado en materia de radio y televisión',
#   'counts': 20},
#  {'curso': 'Gestión de franquicias postales y/o telegráficas', 'counts': 4}]

# %% [markdown]
# # Algoritmo

# %% [markdown]
# **Problema.** Dado un número $N$ de grupos con tamaños $n_i$ (la capacidad máxima del $i$-ésimo grupo), se busca asignar los lugares en cursos a los trabajadores del INE de manera que se priorice a los trabajadores con mayor antigüedad y se maximice la utilización de los grupos. Si no es posible asignar a todos los trabajadores con la configuración dada, se les marcará con un valor de $-1$.
#
# 1. El algoritmo debe determinar si es posible colocar a los trabajadores con la configuración de cursos establecida. De no ser posible, se asignar un valor de $-1$ a las solicitudes que no pudieron tener un grupo asignado.
#
# 2. Debe devolver un diccionario con los ids de los trabajadores, su estado, su antiguedad y el grupo del curso que les fue asignado. Se busca que se llenen los grupos y no queden lugares vacios.
#
# **Entradas.**
# - Una lista con diccionarios que contienen el nombre de un curso y la demanda asociada. La lista debe estar preordenada por demanda de mayor a menor.
# - Una lista con diccionarios que contienen los datos de cada trabajador del INE, incluyendo el curso solicitado. La lista debe estar preordenada por curso (según la demanda) y por antigüedad descendente.
# - $N>0$: Numero de grupos disponibles
# - $n$: Lista de capacidad de asistentes en cada grupo del curso. $n_i>0 \quad \forall i \in \{1,...,N\} $
#
# **Salidas.**
# - Mensaje que indica si no posible la asignación de todos los trabajadores en los cursos.
# - Diccionario con la asignacion de trabajadores con los grupos de los cursos que les corresponde (o $-1$ si no pudo tener un grupo asignado). El diccionario contiene:
#     1. id de trabajador
#     2. Estado
#     3. Antiguedad
#     4. Curso solicitado
#     5. id de grupo asignado (o $-1$ en su defecto)

# %%
def asignar_grupos(lista_demanda, lista_cursos, N, tamanos_grupos):
    # Variables iniciales
    grupos = [[] for _ in range(N)]
    resultado = {'id_trabajador': [], 'estado': [], 'antiguedad': [], 'curso': [], 'curso_id': []}
    cursos_por_grupo = [None for _ in range(N)]
    no_asignados = 0

    # Iteramos sobre los trabajadores ordenados por antiguedad
    lista_demanda = sorted(lista_demanda, key=lambda x: -x['antiguedad'])
    for trabajador in lista_demanda:
        id_trabajador = trabajador['id']
        estado = trabajador['estado']
        antiguedad = trabajador['antiguedad']
        curso = trabajador['curso']
        # Se intenta asignar al trabajador al grupo más adecuado
        asignado = False
        for i in range(N):
            if len(grupos[i]) < tamanos_grupos[i]:
                if cursos_por_grupo[i] is None or cursos_por_grupo[i] == curso:
                    grupos[i].append(id_trabajador)
                    cursos_por_grupo[i] = curso
                    resultado['id_trabajador'].append(id_trabajador)
                    resultado['estado'].append(estado)
                    resultado['antiguedad'].append(antiguedad)
                    resultado['curso'].append(curso)
                    resultado['curso_id'].append(i + 1)
                    asignado = True
                    break
        # Si no se asignó, agregar con grupo_id = -1
        if not asignado:
            resultado['id_trabajador'].append(id_trabajador)
            resultado['estado'].append(estado)
            resultado['antiguedad'].append(antiguedad)
            resultado['curso'].append(curso)
            resultado['curso_id'].append(-1)
            no_asignados += 1

    # Resumen numerico de los grupos
    ocupacion_grupos = [len(grupo) for grupo in grupos]
    # Hay trabajadores no asignados
    if no_asignados > 0:
        print("Advertencia: No fue posible asignar cursos a todos los trabajadores.")
    print(f"Resumen de ocupación de grupos: {ocupacion_grupos}")
    print(f"Trabajadores no asignados: {no_asignados}")
    return resultado

# %% [markdown]
# Probaremos con 160 grupos de 20 personas.

# %%
N = 160
n = [20] * N

# %%
asignaciones = asignar_grupos(lista_demanda, lista_cursos, N, n)
# Out:
# Advertencia: No fue posible asignar cursos a todos los trabajadores.
# Resumen de ocupación de grupos: [20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 4, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 16, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 20, 17, 20, 20, 17, 20, 20, 20, 20, 20, 12, 20, 20, 20, 11, 12, 12, 9, 10, 20, 13, 12, 20, 13, 10]
# Trabajadores no asignados: 114

# %%
cursos_df = pd.DataFrame(asignaciones)

# %%
num_grupo = int(input("Ingrese el número de grupo para visualizar: "))
cursos_df[cursos_df['curso_id'] == num_grupo]
# Out:
#      id_trabajador            estado  antiguedad                  curso  \
# 23            1258            México        32.0  Selección de personal
# 117            385           Jalisco        31.0  Selección de personal
# 118            754  Ciudad de México        31.0  Selección de personal
# 119            801        Guanajuato        31.0  Selección de personal
# 120           1030            México        31.0  Selección de personal
# 121           1200    Aguascalientes        31.0  Selección de personal
# 122            591          Guerrero        31.0  Selección de personal
# 123           1067            México        31.0  Selección de personal
# 124           1190        Guanajuato        31.0  Selección de personal
# 125           1342           Yucatán        31.0  Selección de personal
# 347            302        Guanajuato        30.0  Selección de personal
# 348            596            México        30.0  Selección de personal
# 349            791          Campeche        30.0  Selección de personal
# 350           1598           Jalisco        30.0  Selección de personal
# 351           1732        Nuevo León        30.0  Selección de personal
# 352           2099         Zacatecas        30.0  Selección de personal
# 353              6         Chihuahua        30.0  Selección de personal
# 354            347            México        30.0  Selección de personal
# 355            459            Colima        30.0  Selección de personal
# 356            946           Chiapas        30.0  Selección de personal
#
#      curso_id
# 23          9
# 117         9
# 118         9
# 119         9
# 120         9
# 121         9
# 122         9
# 123         9
# 124         9
# 125         9
# 347         9
# 348         9
# 349         9
# 350         9
# 351         9
# 352         9
# 353         9
# 354         9
# 355         9
# 356         9

# %% [markdown]
# Crear y escribir archivo csv

# %%
pd.DataFrame(asignaciones).to_csv('./Output/asignaciones.csv', index=False)
