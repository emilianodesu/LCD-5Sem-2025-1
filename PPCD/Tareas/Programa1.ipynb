# %% [markdown]
# #### Integrantes
# - Aguilar Martínez Erick Yair
# - Martínez Muñoz Alan Magno
# - Mendoza Hernández Carlos Emiliano

# %% [markdown]
# ### Funciones

# %%
def count_letters(input_txt):
    counts = {}
    input_txt = input_txt.translate(input_txt.maketrans('', '', '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~•')).lower() # Removes punctuation marks
    words = input_txt.split()
    for word in words:
        for letter in word:
            counts[letter] = counts.get(letter, 0) + 1
    # To sort dictionary by descending values
    sorting_lst = []
    for letter, count in counts.items():
        sorting_lst.append((count, letter))
    sorting_lst.sort(reverse=True)
    return sorting_lst

# %%
def count_words(input_lst):
    counts = {}
    input_txt = ' '.join(input_lst)
    input_txt = input_txt.translate(input_txt.maketrans('', '', '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~•')).lower() # Removes punctuation marks
    words = input_txt.split()
    for word in words:
        counts[word] = counts.get(word, 0) + 1
    # To sort dictionary by ascending keys
    counts = sorted(counts.items())
    return counts

# %% [markdown]
# ### Ejemplos

# %%
e1 = count_letters('últimamente hemos tenido varios días muy lluviosos')
for count, letter in e1:
        print(f"{letter:4} {count}")

# %%
txt = ['Hola , cómo estás!', 
       'gana dinero , gana desde casa.',
       'Hola , puedes llamar ahora?',
       'Hola , te puedo llamar mañana?']
e2 = count_words(txt)
for word, count in e2:
        print(f"{word:18} {count}")
# Out:
# ahora              1
# casa               1
# cómo               1
# desde              1
# dinero             1
# estás              1
# gana               2
# hola               3
# llamar             2
# mañana             1
# puedes             1
# puedo              1
# te                 1

# %%
texto = """
 Datos Estadísticos (DGAE-UNAM):
Esta carrera es de ingreso indirecto. El alumno deberá ingresar, en principio, a una carrera de origen a elegir de entre 9 opciones de planes de estudio que son impartidos en la UNAM: Actuaría (Facultad de Ciencias y FES Acatlán), Ciencias de la Computación, Física, Ingeniería en Computación (Facultad de Ingeniería y FES Aragón), Matemáticas, Matemáticas Aplicadas, y Matemáticas Aplicadas y Computación. Ver requisitos adicionales de ingreso.

 Descripción:
Ciencia de Datos es una carrera indispensable para resolver necesidades en el manejo actual y futuro de la información.
Sus labores fundamentales son: seleccionar, limpiar, consolidar y preparar los datos para posteriormente: analizar, predecir, describir comportamientos o conocimientos nuevos para la toma de decisiones. Los dominios de aplicación de esas habilidades pueden ser empresariales, gubernamentales o científicos.
Entre las actividades principales que se llevan a cabo en esta licenciatura destacan:
• Limpieza, curaduría y acondicionamiento de repositorios de datos imperfectos.
• Diseño, proyección y administración de grandes bases de datos.
• Análisis exploratorio de datos para generar hipótesis.
• Presentación y visualización de datos y comunicación de resultados.
Sus egresados podrán también manejar, analizar e innovar modelos matemáticos que les permitan atender campos de aplicación tales como: medicina, biología, mercadotecnia, finanzas, ciencia e investigación.

 Características del aspirante:
Haber cursado y acreditado 4 semestres de la carrera de origen en que se haya inscrito: Actuaría, Ciencias de la Computación, Física, Ingeniería en Computación, Matemáticas, Matemáticas Aplicadas, y Matemáticas Aplicadas y Computación. Además deberá poseer:
Conocimientos:
• Matemáticas básicas (álgebra y cálculo diferencial e integral).
• Computación (fundamentos de algoritmos y programación).
• Inglés (nivel de comprensión oral y escrita A2) dentro del Marco Común Europeo de Referencia para las Lenguas.
• Redacción clara y coherente, y excelente ortografía.
Habilidades para la:
• Observación, abstracción, análisis, síntesis y búsqueda de información.
• Comprensión de lectura.
Actitudes:
• Curiosidad.
• Flexibilidad y adaptabilidad.
Interés por:
• El análisis matemático, estadístico, económico administrativo y computacional.
• La realización de actividades experimentales y la investigación.
Valores:
• Ser responsable y tolerante hacia otras opiniones.

 Condiciones particulares:
Para estudiar Ciencia de Datos se tendrá que tomar en cuenta sus características y ser un alumno de tiempo completo, ya que en principio se deberá cursar y aprobar los semestres correspondientes a la carrera de origen en la entidad académica que la imparta y, luego, enfocarse a hacer lo propio del quinto al octavo semestre, ya específicamente en Ciencia de Datos en el Instituto de Investigaciones en Matemáticas y en Sistemas, o en la Facultad de Estudios Superiores Acatlán.
Asimismo, tendrá que desarrollar otras actividades complementarias (investigación, asistencia a congresos, y concursos de emprendimiento).
Dadas las exigencias propias de la licenciatura que demandan al alumno tenacidad, esfuerzo, disciplina y perseverancia para el análisis y la resolución de problemas que implican mucho tiempo de dedicación, no es recomendable trabajar y se deberá descartar cursar otra carrera de forma simultánea.
El cupo máximo de alumnos a ser aceptado es de 30.

 Campo y mercado de trabajo:
El egresado cuenta con un panorama laboral inmejorable en el mercado nacional e internacional y será un profesionista altamente requerido en todos los sectores económicos.
Podrá incursionar en diversos espacios, dentro de áreas de trabajo como:
• Construcción de modelos estadísticos predictivos.
• Diseño de sistemas de visualización de datos, y de software estadístico y de negocios.
• Inteligencia de negocios y gobierno de datos.
• Manejo de grandes bases de datos.
Tendrá la capacidad para desempeñarse dentro de los sectores público, privado y de servicios en dependencias, organizaciones y empresas relacionadas con: manejo de recursos naturales; protección del ambiente; salud; energía; comunicaciones; transporte; desarrollo sustentable; estadística y geografía; educación; ciencia; economía; desarrollo social y tecnológico; seguridad; turismo; industria; estudios de mercado; negocios y finanzas; o bien, ofrecer sus servicios de consultoría y ejercer la profesión de manera independiente.
"""
palabras = texto.split()

e3 = count_words(palabras)
for word, count in e3:
        print(f"{word:18} {count}")
# Out:
# 30                 1
# 4                  1
# 9                  1
# a                  7
# a2                 1
# abstracción        1
# académica          1
# acatlán            2
# aceptado           1
# acondicionamiento  1
# acreditado         1
# actitudes          1
# actividades        3
# actual             1
# actuaría           2
# adaptabilidad      1
# además             1
# adicionales        1
# administración     1
# administrativo     1
# al                 2
# algoritmos         1
# altamente          1
# alumno             3
# alumnos            1
# ambiente           1
# analizar           2
# análisis           4
# aplicación         2
# aplicadas          4
# aprobar            1
# aragón             1
# asimismo           1
# asistencia         1
# aspirante          1
# atender            1
# bases              2
# bien               1
# biología           1
# básicas            1
# búsqueda           1
# cabo               1
# campo              1
# ...
