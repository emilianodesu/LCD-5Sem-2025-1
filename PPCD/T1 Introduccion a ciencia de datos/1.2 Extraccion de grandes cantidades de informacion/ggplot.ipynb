# %% [markdown]
# # Visualizaciones

# %% [markdown]
# ### ggplot

# %% [markdown]
# Bibliotecas

# %%
library(ggplot2)
library(RColorBrewer)

# %%
str(mpg)
# Out:
# tibble [234 × 11] (S3: tbl_df/tbl/data.frame)
#  $ manufacturer: chr [1:234] "audi" "audi" "audi" "audi" ...
#  $ model       : chr [1:234] "a4" "a4" "a4" "a4" ...
#  $ displ       : num [1:234] 1.8 1.8 2 2 2.8 2.8 3.1 1.8 1.8 2 ...
#  $ year        : int [1:234] 1999 1999 2008 2008 1999 1999 2008 1999 1999 2008 ...
#  $ cyl         : int [1:234] 4 4 4 4 6 6 6 4 4 4 ...
#  $ trans       : chr [1:234] "auto(l5)" "manual(m5)" "manual(m6)" "auto(av)" ...
#  $ drv         : chr [1:234] "f" "f" "f" "f" ...
#  $ cty         : int [1:234] 18 21 20 21 16 18 18 18 16 20 ...
#  $ hwy         : int [1:234] 29 29 31 30 26 26 27 26 25 28 ...
#  $ fl          : chr [1:234] "p" "p" "p" "p" ...
#  $ class       : chr [1:234] "compact" "compact" "compact" "compact" ...

# %%
help(mpg)
# Out:
# mpg                  package:ggplot2                   R Documentation
#
# s
#
# n:
#
#      This dataset contains a subset of the fuel economy data that the
#      EPA makes available on <https://fueleconomy.gov/>. It contains
#      only models which had a new release every year between 1999 and
#      2008 - this was used as a proxy for the popularity of the car.
#
# e:
#
#      mpg
#
# t:
#
#      A data frame with 234 rows and 11 variables:
#
#      manufacturer manufacturer name
#
#      model model name
#
#      displ engine displacement, in litres
#
#      year year of manufacture
#
#      cyl number of cylinders
#
#      trans type of transmission
#
#      drv the type of drive train, where f = front-wheel drive, r = rear
#           wheel drive, 4 = 4wd
#
#      cty city miles per gallon
#
#      hwy highway miles per gallon
#
#      fl fuel type
#
#      class "type" of car

# %%
ggplot(mpg) +
  geom_bar(aes(x = class), fill = "blue") +
  xlab("Tipo de vehículo") +
  ylab("Frecuencia")
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = displ)) +
  geom_histogram(aes(y = after_stat(density)), binwidth = 1, fill = "green") +
  geom_line(stat = "density", col = "gray50", linewidth = 1.5) +
  ylab("Densidad") +
  xlab("Desplazamiento del motor")
# Out:
# plot without title

# %% [markdown]
# ### Datos multivariados

# %%
ggplot(data = mpg, aes(class, cty)) +
  geom_boxplot(fill = "aliceblue") +
  labs(title = "Boxplot", x = "Tipo de auto", y = "Rendimiento")
# Out:
# plot without title

# %%
ggplot(data = mpg, aes(class, cty)) +
  geom_violin(fill = "aliceblue") +
  labs(title = "Violinplot", x = "Tipo de auto", y = "Rendimiento")
# Out:
# plot without title

# %%
install.packages(("tidyverse"))
# Out:
# Warning message:
# "package 'tidyverse' is in use and will not be installed"

# %%
library(tidyverse)#permite usar 'pipes' %>% para secuencias de acciones
mpg_summary <- mpg %>%
  group_by(class) %>%
  summarize(mean_cty = mean(cty),
    std_cty = sd(cty),
    N_cty = n(),
    se = std_cty / sqrt(N_cty),
    x_max = mean_cty + se,
    x_min = mean_cty - se
  )

# %%
mpg_summary$class <- reorder(mpg_summary$class, mpg_summary$mean_cty)
mpg_summary
# Out:
#   class      mean_cty std_cty   N_cty se        x_max    x_min
# 1 2seater    15.40000 0.5477226  5    0.2449490 15.64495 15.15505
# 2 compact    20.12766 3.3854999 47    0.4938259 20.62149 19.63383
# 3 midsize    18.75610 1.9465416 41    0.3039987 19.06010 18.45210
# 4 minivan    15.81818 1.8340219 11    0.5529784 16.37116 15.26520
# 5 pickup     13.00000 2.0463382 33    0.3562218 13.35622 12.64378
# 6 subcompact 20.37143 4.6023377 35    0.7779371 21.14937 19.59349
# 7 suv        13.50000 2.4208791 62    0.3074520 13.80745 13.19255

# %%
ggplot(mpg_summary, aes(mean_cty, y = "class")) +
  geom_errorbar(aes(mean_cty, xmax = x_max, xmin = x_min,
                    y = class), color = "gray60") +
  geom_point(col = "black")
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = reorder(manufacturer, cty, FUN = mean), y = cty)) +
  geom_jitter(colour = "#ff0055", alpha = 0.5, width = 0.1) +
  geom_point(stat = "summary", fun = "mean") +
  geom_errorbar(stat = "summary", fun.data = "mean_se",
                fun.args = list(mult = 1.96), width = 0) +
  labs(x = "fabricante", y = "Rendimiento (media + 95%)") +
  theme_bw() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = reorder(manufacturer, cty, FUN = mean), y = cty)) +
  geom_violin(colour = "#FF00FF", alpha = 0.5, width = 0.1) +
  geom_point(stat = "summary", fun = "mean") +
  geom_errorbar(stat = "summary", fun.data = "mean_se",
                fun.args = list(mult = 1.96), width = 0) +
  labs(x = "fabricante", y = "Rendimiento (media + 95%)") +
  theme_bw() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %%
ggplot(mpg, aes(x = reorder(drv, cty, FUN = mean), y = cty)) +
  geom_violin(colour = "#a71163", alpha = 0.5) +
  geom_point(stat = "summary", fun = "mean") +
  geom_errorbar(stat = "summary", fun.data = "mean_se",
                fun.args = list(mult = 1.96), width = 0) +
  labs(x = "Tipo de tracción", y = "Rendimiento (media+95%)") +
  theme_bw() +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))
# Out:
# plot without title

# %%
# Semilla para replicar resultados
set.seed(3939394)
data <- mpg[sample.int(nrow(mpg), size = 200, replace = FALSE), ]
#Reordenamiento
data$manufacturer <- reorder(data$manufacturer, data$cty)

# %%
medianas <- aggregate(data$displ, list(data$manufacturer), FUN = median)
names(medianas) <- c("manufacturer", "displ")
medianas$y_val <- as.numeric(medianas$manufacturer)
head(medianas)
# Out:
#   manufacturer displ y_val
# 1 lincoln      5.4   1
# 2 land rover   4.3   2
# 3 dodge        4.7   3
# 4 mercury      4.0   4
# 5 ford         4.6   5
# 6 jeep         4.2   6

# %%
ggplot(data, aes(x = displ, y = manufacturer)) +
  geom_point(position = position_jitter(h = .4), alpha = 0.1) +
  geom_segment(data = medianas, col = "red",
               aes(x = displ, xend = displ,
                   y = y_val - .4, yend = y_val + .4)) +
  labs(x = "Desplazamiento", y = "Fabricante")
# Out:
# plot without title

# %%
medianas <- aggregate(data$displ,
                      list(drv = data$drv,
                           manufacturer = data$manufacturer),
                      FUN = median)
names(medianas) <- c("drv", "manufacturer", "displ")
medianas$y_val <- as.numeric(medianas$manufacturer)
jit_val <- 0.6
head(medianas)
# Out:
#   drv manufacturer displ y_val
# 1 r   lincoln      5.40  1
# 2 4   land rover   4.30  2
# 3 4   dodge        4.70  3
# 4 f   dodge        3.55  3
# 5 4   mercury      4.00  4
# 6 4   ford         4.60  5

# %%
ggplot(data, aes(x = displ, y = manufacturer, group = drv, col = drv)) +
  geom_point(position = position_jitter(h = jit_val), alpha = 0.1) +
  geom_segment(data = medianas,
               aes(x = displ, xend = displ, group = drv, col = drv,
                   y = y_val - jit_val, yend = y_val + jit_val)) +
  labs(x = "Desplazamiento", y = "Fabricante")
# Out:
# plot without title
